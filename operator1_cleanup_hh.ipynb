# %%
import pandas as pd
import numpy as np
import matplotlib as plt

import re

# %%
df = pd.read_csv('../airline_safety/data/aviation_data.csv')

# %%
df.head()
# Out:
#        NtsbNo EventType    Mkey             EventDate         City      State  \
# 0  DCA24LA051       ACC  193561  2023-12-19T19:30:00Z    St. Louis   Missouri
# 1  DCA24LA034       INC  193459  2023-11-30T08:14:00Z      Kahului     Hawaii
# 2  ENG24FA003       INC  193272  2023-10-18T17:15:00Z      Memphis  Tennessee
# 3  DCA24FA002       ACC  193196  2023-10-05T00:47:00Z  Chattanooga  Tennessee
# 4  DCA23LA468       ACC  193204  2023-09-30T16:00:00Z       Denver   Colorado
#
#          Country ReportNo       N  HasSafetyRec  ... PurposeOfFlight  FAR  \
# 0  United States      NaN  N8514F         False  ...             NaN  121
# 1  United States      NaN  N494HA         False  ...             NaN  121
# 2  United States      NaN  N287FE         False  ...             NaN  121
# 3  United States      NaN  N977FD         False  ...             NaN  121
# 4  United States      NaN  N37560         False  ...             NaN  121
#
# ...

# %%
def camel_to_snake(col):
    return re.sub(r'(?<!^)(?=[A-Z])', '_', col).lower()

# %%
df.head()
# Out:
#        NtsbNo EventType    Mkey             EventDate         City      State  \
# 0  DCA24LA051       ACC  193561  2023-12-19T19:30:00Z    St. Louis   Missouri
# 1  DCA24LA034       INC  193459  2023-11-30T08:14:00Z      Kahului     Hawaii
# 2  ENG24FA003       INC  193272  2023-10-18T17:15:00Z      Memphis  Tennessee
# 3  DCA24FA002       ACC  193196  2023-10-05T00:47:00Z  Chattanooga  Tennessee
# 4  DCA23LA468       ACC  193204  2023-09-30T16:00:00Z       Denver   Colorado
#
#          Country ReportNo       N  HasSafetyRec  ... PurposeOfFlight  FAR  \
# 0  United States      NaN  N8514F         False  ...             NaN  121
# 1  United States      NaN  N494HA         False  ...             NaN  121
# 2  United States      NaN  N287FE         False  ...             NaN  121
# 3  United States      NaN  N977FD         False  ...             NaN  121
# 4  United States      NaN  N37560         False  ...             NaN  121
#
# ...

# %%
df.columns = [camel_to_snake(col) for col in df.columns]

# %%
df.head()
# Out:
#       ntsb_no event_type    mkey            event_date         city  \
# 0  DCA24LA051        ACC  193561  2023-12-19T19:30:00Z    St. Louis
# 1  DCA24LA034        INC  193459  2023-11-30T08:14:00Z      Kahului
# 2  ENG24FA003        INC  193272  2023-10-18T17:15:00Z      Memphis
# 3  DCA24FA002        ACC  193196  2023-10-05T00:47:00Z  Chattanooga
# 4  DCA23LA468        ACC  193204  2023-09-30T16:00:00Z       Denver
#
#        state        country report_no       n  has_safety_rec  ...  \
# 0   Missouri  United States       NaN  N8514F           False  ...
# 1     Hawaii  United States       NaN  N494HA           False  ...
# 2  Tennessee  United States       NaN  N287FE           False  ...
# 3  Tennessee  United States       NaN  N977FD           False  ...
# 4   Colorado  United States       NaN  N37560           False  ...
#
#   purpose_of_flight f_a_r air_craft_damage  weather_condition  \
# 0               NaN   121      Substantial                VMC
# ...

# %%
#list of columns worth keeping to streamline cleaning
columns_to_keep = ['event_type',
                   'event_date',
                   'city', 'state',
                   'country',
                   'n',
                   'highest_injury_level',
                   'fatal_injury_count',
                   'serious_injury_count',
                   'minor_injury_count',
                   'probable_cause',
                   'latitude',
                   'longitude',
                   'make',
                   'model',
                   'airport_i_d',
                   'airport_name',
                   'number_of_engines',
                   'air_craft_damage',
                   'weather_condition',
                   'operator',
                  ]

airline_filtered_df = df[columns_to_keep].copy()

# %%
pd.set_option('display.max_rows', 1000)

# %%
airline_filtered_df.rename(columns = {'airport_i_d':'airport_id', 'air_craft_damage':'aircraft_damage'}, inplace = True)

# %%
airline_filtered_df['event_type'] = airline_filtered_df['event_type'].str.replace('OCC', 'INC')

# %%
airline_filtered_df['event_date'] = airline_filtered_df['event_date'].str[:10]
airline_filtered_df['event_date'] = airline_filtered_df['event_date'].str[:10]

# %%
airline_filtered_df.head(50)
# Out:
#    event_type  event_date             city           state            country  \
# 0         ACC  2023-12-19        St. Louis        Missouri      United States
# 1         INC  2023-11-30          Kahului          Hawaii      United States
# 2         INC  2023-10-18          Memphis       Tennessee      United States
# 3         ACC  2023-10-05      Chattanooga       Tennessee      United States
# 4         ACC  2023-09-30           Denver        Colorado      United States
# 5         ACC  2023-09-28        Ann Arbor        Michigan      United States
# 6         ACC  2023-09-25    Carribean Sea             NaN            Jamaica
# 7         INC  2023-09-24        Guayaquil             NaN            Ecuador
# 8         INC  2023-09-18        Melbourne             NaN          Australia
# 9         ACC  2023-09-07           Hebron        Kentucky      United States
# 10        INC  2023-09-01           Prague             NaN     Czech Republic
# ...

# %%
airline_filtered_df.columns
# Out:
# Index(['event_type', 'event_date', 'city', 'state', 'country', 'n',
#        'highest_injury_level', 'fatal_injury_count', 'serious_injury_count',
#        'minor_injury_count', 'probable_cause', 'latitude', 'longitude', 'make',
#        'model', 'airport_id', 'airport_name', 'number_of_engines',
#        'aircraft_damage', 'weather_condition', 'operator'],
#       dtype='object')

# %% [markdown]
# ## Start of Holly Code to clean up Operator Column

# %%
#make all lower case
airline_filtered_df['operator'] = airline_filtered_df['operator'].str.lower()

# %%
#two operators listed, separated into an operator 2 column
airline_filtered_df[['operator1', 'operator2']] = airline_filtered_df['operator'].str.split(',', n=1, expand=True)

# %%
#clean up operator column, so all airlines are spelled and listed correctly USING str.replace(). 

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('united airlines inc', 'united')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('american airlines inc', 'american')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('delta air lines', 'delta')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('delta airlines inc', 'delta')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('hawaiian airlines inc', 'hawaiian')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('southwest airlines co', 'southwest')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('federal express corporation', 'federal express')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('federal express', 'federal express')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('alaska airlines inc', 'alaska')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('united airlines.', 'united')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('gojet airlines, llc.', 'gojet')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('united parcel service', 'ups')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('drelat air lines, inc.', 'delta')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('allegiant air, llc', 'allegiant air')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('united air lines inc', 'united')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('psa airlines, inc.', 'psa')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('psa airlines inc', 'psa')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('expressjet', 'expressjet airlines')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('atlas air , inc.', 'atlas air')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('express jet', 'expressjet airlines')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('american eagle airlines inc', 'american eagle airlines')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('delta airlines, inc.', 'delta')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('spirit airlines, inc.', 'spirit')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('southwest airlines, co.', 'southwest')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('expressjet airlines airlines', 'expressjet airlines')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('expressjet airlines airlines inc', 'expressjet airlines')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('united airlnes inc', 'united')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('psa airlines.', 'psa')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('united air lines', 'united')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('alaska airlines, inc.', 'alaska')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('kalitta charters ii llc', 'kalitta air')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('fedex express', 'fedex express corp')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('great lakes aviation', 'great lakes')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('ups airlines company', 'ups')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('air tran airways', 'airtran')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('kalitta flying service inc', 'kalitta air')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('soutwest airlines inc.', 'southwest')

airline_filtered_df['operator1'] = airline_filtered_df['operator1'].str.replace('flying tiger', 'flying tigers')

# %% [markdown]
# ### str.contains() cleanup

# %%
airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('united', na=False), 'operator1'] = 'united'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('federal', na=False), 'operator1'] = 'federal express'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('ups', na=False), 'operator1'] = 'ups'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('delta', na=False), 'operator1'] = 'delta'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('eagle', na=False), 'operator1'] = 'american eagle airlines'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('fedex', na=False), 'operator1'] = 'federal express'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('alaska', na=False), 'operator1'] = 'alaska'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('spirit', na=False), 'operator1'] = 'spirit'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('frontier', na=False), 'operator1'] = 'frontier'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('southwest', na=False), 'operator1'] = 'southwest'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('wisconsin', na=False), 'operator1'] = 'air wisconsin'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('jetblue', na=False), 'operator1'] = 'jetblue airway'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('us', na=False), 'operator1'] = 'us airways'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('allegiant', na=False), 'operator1'] = 'allegiant air'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('canada', na=False), 'operator1'] = 'air canada'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('northwest', na=False), 'operator1'] = 'northwest'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('frontier', na=False), 'operator1'] = 'frontier'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('continental', na=False), 'operator1'] = 'continental'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('eagle', na=False), 'operator1'] = 'american'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('s.w.', na=False), 'operator1'] = 'southwest'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('american', na=False), 'operator1'] = 'american'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('blue', na=False), 'operator1'] = 'jetblue'

airline_filtered_df.loc[airline_filtered_df['operator1'].str.contains('pinnacle', na=False), 'operator1'] = 'pinnacle'

# %%
#dropping operator2 columns (not needed for our models)
airline_filtered_df.drop(columns=['operator2'])
# Out:
#      event_type  event_date         city                 state        country  \
# 0           ACC  2023-12-19    St. Louis              Missouri  United States
# 1           INC  2023-11-30      Kahului                Hawaii  United States
# 2           INC  2023-10-18      Memphis             Tennessee  United States
# 3           ACC  2023-10-05  Chattanooga             Tennessee  United States
# 4           ACC  2023-09-30       Denver              Colorado  United States
# ...         ...         ...          ...                   ...            ...
# 2558        ACC  1982-01-23       BOSTON         Massachusetts  United States
# 2559        INC  1982-01-22   LOUISVILLE              Kentucky  United States
# 2560        ACC  1982-01-13   WASHINGTON  District of Columbia  United States
# 2561        ACC  1982-01-13   WASHINGTON  District of Columbia  United States
# 2562        INC  1982-01-12      CHICAGO              Illinois  United States
#
# ...

# %%
airline_filtered_df.head()
# Out:
#   event_type  event_date         city      state        country       n  \
# 0        ACC  2023-12-19    St. Louis   Missouri  United States  N8514F
# 1        INC  2023-11-30      Kahului     Hawaii  United States  N494HA
# 2        INC  2023-10-18      Memphis  Tennessee  United States  N287FE
# 3        ACC  2023-10-05  Chattanooga  Tennessee  United States  N977FD
# 4        ACC  2023-09-30       Denver   Colorado  United States  N37560
#
#   highest_injury_level  fatal_injury_count  serious_injury_count  \
# 0                  NaN                   0                     0
# 1                Minor                   0                     0
# 2                  NaN                   0                     0
# 3                  NaN                   0                     0
# 4                  NaN                   0                     0
#
#    minor_injury_count  ...    make    model  airport_id          airport_name  \
# ...

# %% [markdown]
# ----

# %%
#dropping null's in airport_id 
airline_filtered_df.dropna(subset=['airport_id'], inplace=True)

# %%
airline_filtered_df.shape
# Out:
# (1612, 23)

# %%
#dropping null's in operator1 column
airline_filtered_df.dropna(subset=['operator1'], inplace=True)

# %%
airline_filtered_df.shape
# Out:
# (1119, 23)

# %%
airline_filtered_df.head()
# Out:
#    event_type  event_date         city       state        country  \
# 1         INC  2023-11-30      Kahului      Hawaii  United States
# 3         ACC  2023-10-05  Chattanooga   Tennessee  United States
# 4         ACC  2023-09-30       Denver    Colorado  United States
# 14        ACC  2023-08-21    Santa Ana  California  United States
# 17        INC  2023-08-11    San Diego  California  United States
#
#                  n highest_injury_level  fatal_injury_count  \
# 1           N494HA                Minor                   0
# 3           N977FD                  NaN                   0
# 4           N37560                  NaN                   0
# 14          N516AS                  NaN                   0
# 17  N7734H, N564HV                  NaN                   0
#
#     serious_injury_count  minor_injury_count  ...  \
# 1                      0                   1  ...
# 3                      0                   0  ...
# ...

# %%
airline_filtered_df['operator1'].isnull().sum()
# Out:
# 0

# %%
airline_filtered_df.shape
# Out:
# (1119, 23)

# %% [markdown]
# ## Aircraft_damage CleanUp

# %%
airline_filtered_df['aircraft_damage'].value_counts()
# Out:
# aircraft_damage
# Minor                      331
# Substantial                301
# None,None                   56
# Destroyed                   33
# Minor,Substantial           31
# Minor,Minor                 18
# Substantial,Minor           14
# Substantial,Substantial     12
# Minor,None                   4
# Substantial,None             2
# None,Substantial             2
# Destroyed,Substantial        2
# Substantial,Destroyed        1
# None,Minor                   1
# Destroyed,Destroyed          1
# Name: count, dtype: int64

# %%
#separating damage, will only be using first damage listed
airline_filtered_df[['aircraft_damage1', 'aircraft_damage2']] = airline_filtered_df['aircraft_damage'].str.split(',', n=1, expand=True)

# %%
airline_filtered_df['aircraft_damage1'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1119 entries, 1 to 2562
# Series name: aircraft_damage1
# Non-Null Count  Dtype
# --------------  -----
# 809 non-null    object
# dtypes: object(1)
# memory usage: 17.5+ KB

# %%
airline_filtered_df['aircraft_damage2'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1119 entries, 1 to 2562
# Series name: aircraft_damage2
# Non-Null Count  Dtype
# --------------  -----
# 144 non-null    object
# dtypes: object(1)
# memory usage: 17.5+ KB

# %%
airline_filtered_df['aircraft_damage1'].isnull().sum()
# Out:
# 310

# %%
#dropping aircraft_damage2 column (not needed for our models)
airline_filtered_df.drop(columns=['aircraft_damage2'])
# Out:
#      event_type  event_date          city         state        country  \
# 1           INC  2023-11-30       Kahului        Hawaii  United States
# 3           ACC  2023-10-05   Chattanooga     Tennessee  United States
# 4           ACC  2023-09-30        Denver      Colorado  United States
# 14          ACC  2023-08-21     Santa Ana    California  United States
# 17          INC  2023-08-11     San Diego    California  United States
# ...         ...         ...           ...           ...            ...
# 2554        ACC  1982-02-17         MIAMI       Florida  United States
# 2556        INC  1982-02-15       ONTARIO    California  United States
# 2557        ACC  1982-02-03  PHILADELPHIA  Pennsylvania  United States
# 2559        INC  1982-01-22    LOUISVILLE      Kentucky  United States
# 2562        INC  1982-01-12       CHICAGO      Illinois  United States
#
#                    n highest_injury_level  fatal_injury_count  \
# ...

# %%
#replace NaN with None, after reviewing other columns
airline_filtered_df['aircraft_damage1'] = airline_filtered_df['aircraft_damage1'].replace(np.nan, 'None')

# %%
airline_filtered_df['aircraft_damage1'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1119 entries, 1 to 2562
# Series name: aircraft_damage1
# Non-Null Count  Dtype
# --------------  -----
# 1119 non-null   object
# dtypes: object(1)
# memory usage: 17.5+ KB

# %%
airline_filtered_df['aircraft_damage1'].value_counts()
# Out:
# aircraft_damage1
# Minor          384
# None           369
# Substantial    330
# Destroyed       36
# Name: count, dtype: int64

# %% [markdown]
# ### Dropping unnecessary columns

# %%
airline_filtered_df.columns
# Out:
# Index(['event_type', 'event_date', 'city', 'state', 'country', 'n',
#        'highest_injury_level', 'fatal_injury_count', 'serious_injury_count',
#        'minor_injury_count', 'probable_cause', 'latitude', 'longitude', 'make',
#        'model', 'airport_id', 'airport_name', 'number_of_engines',
#        'aircraft_damage', 'weather_condition', 'operator', 'operator1',
#        'operator2', 'aircraft_damage1', 'aircraft_damage2'],
#       dtype='object')

# %%
airline_filtered_df.drop(columns=['city', 'state', 'country','latitude', 'longitude', 'airport_id', 'airport_name', 'number_of_engines',
       'aircraft_damage', 'weather_condition', 'operator', 'operator2', 'aircraft_damage2'])
# Out:
#      event_type  event_date               n highest_injury_level  \
# 1           INC  2023-11-30          N494HA                Minor
# 3           ACC  2023-10-05          N977FD                  NaN
# 4           ACC  2023-09-30          N37560                  NaN
# 14          ACC  2023-08-21          N516AS                  NaN
# 17          INC  2023-08-11  N7734H, N564HV                  NaN
# ...         ...         ...             ...                  ...
# 2554        ACC  1982-02-17           N4734              Serious
# 2556        INC  1982-02-15          N73717                  NaN
# 2557        ACC  1982-02-03          N1814U              Serious
# 2559        INC  1982-01-22           N18FE                  NaN
# 2562        INC  1982-01-12          N31031                  NaN
#
#       fatal_injury_count  serious_injury_count  minor_injury_count  \
# 1                      0                     0                   1
# ...

# %%
df = pd.read_csv('
