# %% [markdown]
# # Data Exploration Through Visualization
# ___

# %% [markdown]
# Data exploration of our cleaned airline dataset.  Please see the SpaCy notebook for word visualizations on the probable_cause column.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import MaxNLocator

# %%
airline_df = pd.read_csv('../data/text_processed_aviation_data.csv')

# %%
airline_df.head()
# Out:
#   event_type  event_date     tail_number highest_injury_level  \
# 0        INC  2023-11-30          N494HA                minor
# 1        ACC  2023-09-30          N37560                 none
# 2        ACC  2023-08-21          N516AS                 none
# 3        INC  2023-08-11  N7734H, N564HV                 none
# 4        INC  2023-08-03          N649JB                 none
#
#    fatal_injury_count  serious_injury_count  minor_injury_count  \
# 0                   0                     0                   1
# 1                   0                     0                   0
# 2                   0                     0                   0
# 3                   0                     0                   0
# 4                   0                     0                   0
#
#       probable_cause   latitude   longitude airport_id   operator    make  \
# 0  reportunavailable  20.899501 -156.429730        OGG   hawaiian  boeing
# 1  reportunavailable  39.849312 -104.673820        DEN     united  boeing
# 2  reportunavailable  33.675701 -117.867990        SNA     alaska  boeing
# 3  reportunavailable  32.730189 -117.175620        SAN  southwest  boeing
# 4  reportunavailable  30.486167  -81.750781        JAX    jetblue  airbus
#
#   aircraft_damage model
# 0           Minor   717
# 1     Substantial   737
# 2     Substantial   737
# 3       no_damage   737
# 4       no_damage  A320

# %%
# I want the sum of fatalities per airline
fatalities_per_operator = pd.DataFrame(airline_df.groupby('operator')['fatal_injury_count'].sum().reset_index())

#I added this because there were a handful of airlines that didn't have any fatalities and it make the chart look
# skewed.
fatalities_per_operator = fatalities_per_operator[fatalities_per_operator['fatal_injury_count'] > 0]

# %%
fatalities_per_operator = fatalities_per_operator.sort_values(by = 'fatal_injury_count', ascending = False)

# %%
# Plot Settings
plt.figure(figsize = (12, 8))
sns.set_theme(style="whitegrid")
plt.tight_layout()

sns.set_color_codes("pastel")
sns.barplot(data = fatalities_per_operator,
            x = 'operator',
            y = 'fatal_injury_count',
           color = 'g')

# Plot Labels
plt.title('Number of Fatalities By Airline', size = 30)

plt.xlabel('Airline', size = 25)
plt.xticks(size = 16, rotation = 20)
plt.ylabel('Fatalities', size = 25)

#Save and export
plt.savefig('../images/number_fatalities_by_airline.png', dpi = 192);

# %%
#Separate dataframe by accident and incident.  Need to make copies to prevent error warnings
accidents_only = airline_df[airline_df['event_type'] == 'ACC'].copy()
incidents_only = airline_df[airline_df['event_type'] == 'INC'].copy()

# %%
accidents_only['event_date'] = pd.to_datetime(accidents_only['event_date'])
incidents_only['event_date'] = pd.to_datetime(incidents_only['event_date'])

# %%
accidents_only['year'] = accidents_only['event_date'].dt.year
incidents_only['year'] = incidents_only['event_date'].dt.year

# %% [markdown]
# This was a challenge to get the kind of dataframe I wanted.  Count of accidents per year. I referenced [this](https://stackoverflow.com/questions/72916328/pandas-groupby-newbie-conundrum) article because I knew I wanted to group them together somehow. The unstack [documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.unstack.html) was also referenced. Also referenced ChatGPT for help with grouping. Size counts the number of instances in an array.  The output is a series, so .unstack() transforms it into a dataframe with the calculated values as a column.

# %%
accidents_by_year = accidents_only.groupby(['year', 'event_type']).size().unstack(fill_value=0)
incidents_by_year = incidents_only.groupby(['year', 'event_type']).size().unstack(fill_value=0)

# %%
#Finally
accidents_by_year.head(), incidents_by_year.head()
# Out:
# (event_type  ACC
#  year
#  1982          4
#  1983          1
#  1984          1
#  1985          1
#  1986          6,
#  event_type  INC
#  year
#  1982          5
#  1983          7
#  1984          3
#  1985          4
#  1986          3)

# %% [markdown]
# Referenced [this](https://stackoverflow.com/questions/12050393/how-to-force-the-y-axis-to-only-use-integers) so that we could get only integers for the y-axis.

# %%
# Plot Settings
plt.figure(figsize = (12, 8))
sns.set_theme(style="whitegrid")
plt.tight_layout()

ax = plt.figure().gca()
ax.yaxis.set_major_locator(MaxNLocator(integer=True))

#Plot
sns.lineplot(data = accidents_by_year, 
             x = 'year',
             y = 'ACC',
            color = 'hotpink',
            label = 'Accident')

sns.lineplot(data = incidents_by_year, 
             x = 'year',
             y = 'INC',
            color = 'teal',
            label = 'Incident')

# Titles and axis
plt.title('Commercial Airline Accidents Per Year', size = 20)
plt.ylabel('Occurances', size = 15)
plt.xlabel('Year', size = 15)

plt.legend()

plt.savefig('../images/acc_and_inc_per_year.png', dpi = 192);

# %%
injuries_df = airline_df.groupby(['highest_injury_level', 'operator']).size().unstack(fill_value=0)

# %%
injuries_df
# Out:
# operator              alaska  allegiant  american  continental  delta  \
# highest_injury_level
# fatal                      2          0         2            1      0
# minor                      4          1        21           10      5
# none                      14          4        74           37     77
# serious                    2          1        32            6     20
#
# operator              frontier  hawaiian  jetblue  southwest  spirit  \
# highest_injury_level
# fatal                        0         0        0          1       0
# minor                        1         1        2          7       1
# none                        10         6        7         40       4
# serious                      4         0        2         14       0
#
# operator              sun country  united  us airways
# highest_injury_level
# fatal                           0       2           5
# minor                           0      12           5
# none                            3      62          32
# serious                         1      13          10

# %%
injuries_df = injuries_df.T

# %%
injuries_df
# Out:
# highest_injury_level  fatal  minor  none  serious
# operator
# alaska                    2      4    14        2
# allegiant                 0      1     4        1
# american                  2     21    74       32
# continental               1     10    37        6
# delta                     0      5    77       20
# frontier                  0      1    10        4
# hawaiian                  0      1     6        0
# jetblue                   0      2     7        2
# southwest                 1      7    40       14
# spirit                    0      1     4        0
# sun country               0      0     3        1
# united                    2     12    62       13
# us airways                5      5    32       10

# %%
injuries_df.reset_index(inplace = True)

# %% [markdown]
# Trying to make a bargraph with one bar for each injury level per airline.  Hank had mentioned melting before, which is a category on the first column with values in other columns, but listed invidually. Referenced [this](https://www.geeksforgeeks.org/python-pandas-melt/) website.

# %%
injuries_df_melted = injuries_df.melt(id_vars='operator', var_name='highest_injury_level', value_name='count')

# %%
injuries_df_melted.head()
# Out:
#       operator highest_injury_level  count
# 0       alaska                fatal      2
# 1    allegiant                fatal      0
# 2     american                fatal      2
# 3  continental                fatal      1
# 4        delta                fatal      0

# %%
#Setup
plt.figure(figsize = (12, 8))
sns.set_theme(style="whitegrid")
plt.tight_layout()

#Plot
sns.barplot(data=injuries_df_melted, x='operator', y='count', hue='highest_injury_level')

# Titles and axis
plt.title('Injury Levels By Airline', size = 30)
plt.ylabel('Occurances', size = 20)
plt.xlabel('Airline', size = 20)
plt.xticks(rotation = 15, size = 12)
plt.yticks(size = 15)
plt.legend(title = 'Higest Injury Level')

plt.savefig('../images/injury_level_by_airline.png', dpi = 192);
